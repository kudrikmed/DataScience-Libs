# %% [markdown]
# # Задание 1

# %%
import pandas as pd
import numpy as np

# %%
authors = pd.DataFrame({'author_id': [1, 2, 3], 'author_name': ['Тургенев', 'Чехов', 'Островский']})
book = pd.DataFrame({'author_id': [1, 1, 1, 2, 2, 3, 3], 'book_title': ['Отцы и дети', 'Рудин', 'Дворянское гнездо', 'Толстый и тонкий', 'Дама с собачкой', 'Гроза', 'Таланты и поклонники'], 'price': [450, 300, 350, 500, 450, 370, 290]})

# %%
print(authors)
print(book)
# Out:
#    author_id author_name
# 0          1    Тургенев
# 1          2       Чехов
# 2          3  Островский
#    author_id            book_title  price
# 0          1           Отцы и дети    450
# 1          1                 Рудин    300
# 2          1     Дворянское гнездо    350
# 3          2      Толстый и тонкий    500
# 4          2       Дама с собачкой    450
# 5          3                 Гроза    370
# 6          3  Таланты и поклонники    290

# %% [markdown]
# # Задание 2

# %%
authors_price = pd.merge(authors, book, on = "author_id", how = "outer")
print(authors_price)
# Out:
#    author_id author_name            book_title  price
# 0          1    Тургенев           Отцы и дети    450
# 1          1    Тургенев                 Рудин    300
# 2          1    Тургенев     Дворянское гнездо    350
# 3          2       Чехов      Толстый и тонкий    500
# 4          2       Чехов       Дама с собачкой    450
# 5          3  Островский                 Гроза    370
# 6          3  Островский  Таланты и поклонники    290

# %% [markdown]
# # Задание 3

# %%
top5 = authors_price.sort_values(by=["price"], ascending = False).head(5)
print(top5)
# Out:
#    author_id author_name         book_title  price
# 3          2       Чехов   Толстый и тонкий    500
# 0          1    Тургенев        Отцы и дети    450
# 4          2       Чехов    Дама с собачкой    450
# 5          3  Островский              Гроза    370
# 2          1    Тургенев  Дворянское гнездо    350

# %% [markdown]
# # Задание 4

# %%
authors_stat = authors_price.groupby('author_name').agg({"price": ["max", "min", "mean"]})
authors_stat.rename(columns={"max": "max_price", "min": "min_price", "mean": "mean_price"})
# Out:
#                 price
#             max_price min_price  mean_price
# author_name
# Островский        370       290  330.000000
# Тургенев          450       300  366.666667
# Чехов             500       450  475.000000

# %% [markdown]
# # Задание 5

# %%
 authors_price = authors_price.assign(cover = ['твердая', 'мягкая', 'мягкая', 'твердая', 'твердая', 'мягкая', 'мягкая']).copy()

# %%
print(authors_price)
# Out:
#    author_id author_name            book_title  price    cover
# 0          1    Тургенев           Отцы и дети    450  твердая
# 1          1    Тургенев                 Рудин    300   мягкая
# 2          1    Тургенев     Дворянское гнездо    350   мягкая
# 3          2       Чехов      Толстый и тонкий    500  твердая
# 4          2       Чехов       Дама с собачкой    450  твердая
# 5          3  Островский                 Гроза    370   мягкая
# 6          3  Островский  Таланты и поклонники    290   мягкая

# %%
book_info = pd.pivot_table(authors_price, index='author_name', columns = "cover", values = "price", fill_value = 0, aggfunc = np.sum)

# %%
print(book_info)
# Out:
# cover        мягкая  твердая
# author_name
# Островский      660        0
# Тургенев        650      450
# Чехов             0      950

# %%
book_info.to_pickle("books")

# %%
book_info2 = pd.read_pickle("books")

# %%
book_info
# Out:
# cover        мягкая  твердая
# author_name
# Островский      660        0
# Тургенев        650      450
# Чехов             0      950

# %%
book_info2
# Out:
# cover        мягкая  твердая
# author_name
# Островский      660        0
# Тургенев        650      450
# Чехов             0      950
